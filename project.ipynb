# %% [markdown]
# # Option Pricing

# %%
# from nsepy import get_history
# from datetime import date
# from nsetools import Nse
# from pprint import pprint
from nsepython import *

# %%
# data=get_history(symbol='SBIN',start=date(2015,1,1),end=date(2015,12,31))
# # data[['Close']].plot()
# nse = Nse()
# print(nse)
print(indices)
# Out:
# ['NIFTY', 'FINNIFTY', 'BANKNIFTY']

# %%
# q = nse.get_quote('infy')
# pprint(q)
print(nse_eq("ADANIENT"))
# Out:
# {'info': {'symbol': 'ADANIENT', 'companyName': 'Adani Enterprises Limited', 'industry': 'TRADING', 'activeSeries': ['EQ'], 'debtSeries': [], 'tempSuspendedSeries': [], 'isFNOSec': True, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': False, 'isSuspended': False, 'isETFSec': False, 'isDelisted': False, 'isin': 'INE423A01024', 'isTop10': False, 'identifier': 'ADANIENTEQN'}, 'metadata': {'series': 'EQ', 'symbol': 'ADANIENT', 'isin': 'INE423A01024', 'status': 'Listed', 'listingDate': '04-Jun-1997', 'industry': 'Trading - Minerals', 'lastUpdateTime': '13-Apr-2023 16:00:00', 'pdSectorPe': 21.71, 'pdSymbolPe': 149.51, 'pdSectorInd': 'NIFTY 500                                         '}, 'securityInfo': {'boardStatus': 'Main', 'tradingStatus': 'Active', 'tradingSegment': 'Normal Market', 'sessionNo': '-', 'slb': 'Yes', 'classOfShare': 'Equity', 'derivatives': 'Yes', 'surveillance': {'surv': None, 'desc': None}, 'faceValue': 1, 'issuedSize': 1140001121}, 'priceInfo': {'lastPrice': 1869.5, 'c
# ...

# %%
print(nse_eq("JUSTDIAL")['priceInfo']['close'])
# Out:
# 642.1

# %%
print(nse_past_results('JUSTDIAL'))
# Out:
# {'resCmpData': [{'re_to_dt': '31-DEC-2022', 're_from_dt': '01-OCT-2022', 're_create_dt': '14-JAN-2023', 're_res_type': 'U', 're_excepn_items_new': '0', 're_desc_note_seg': '-', 're_staff_cost': '16732', 're_tot_exp_exc_pro_cont': None, 're_grs_npa': None, 're_int_expd': None, 're_con_pro_loss': '7527', 're_net_sale': '22137', 're_oth_exp': '2693', 're_rawmat_consump': '0', 're_diluted_eps': None, 're_inc_dre_sttr': '0', 're_pur_trd_goods': '0', 're_face_val': '10', 're_income_inv': None, 're_deff_tax': '1172', 're_share_associate': '0', 're_ret_asset': None, 're_proloss_ord_act': '7527', 're_notes_to_ac': '', 're_grs_npa_per': None, 're_excepn_items': None, 're_int_new': '225', 're_pro_los_frm_dis_opr': '0', 're_goi_per_shhd': None, 're_basic_eps_for_cont_dic_opr': '8.93', 're_oth_oper_exp': None, 're_remarks': None, 're_oth_pro_cont': None, 're_seg_remarks': None, 're_face_value_debt': None, 're_dilut_eps_for_cont_dic_opr': '8.86', 're_desc_note_fin': "Notes:      1. The Audit Commi
# ...

# %%
symbol = "RELIANCE"
series = "EQ"
start_date = "1-04-2013"
end_date ="31-03-2023"
data=equity_history(symbol,series,start_date,end_date)
# print(equity_history(symbol,series,start_date,end_date)["CH_CLOSING_PRICE"])
# Out:
# c:\Python310\lib\site-packages\nsepython\rahu.py:544: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total=total.append(equity_history_virgin(symbol,series,start_date,temp_date))
# c:\Python310\lib\site-packages\nsepython\rahu.py:544: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total=total.append(equity_history_virgin(symbol,series,start_date,temp_date))
# c:\Python310\lib\site-packages\nsepython\rahu.py:544: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total=total.append(equity_history_virgin(symbol,series,start_date,temp_date))
# ...

# %%
data
# Out:
#                            _id CH_SYMBOL CH_SERIES CH_MARKET_TYPE  \
# 0     64184add4cca9b00071d0c75  RELIANCE        EQ              N
# 1     64199c7ef23e5d0007762ea6  RELIANCE        EQ              N
# 2     641aede070c37800075eb380  RELIANCE        EQ              N
# 3     641c3f614052850007ffb312  RELIANCE        EQ              N
# 4     642836527ae9d000071170b8  RELIANCE        EQ              N
# ...                        ...       ...       ...            ...
# 2544  641e9ff4adde0b0007cf5759  RELIANCE        EQ              N
# 2545  641e9ffe2c03d7000701f842  RELIANCE        EQ              N
# 2546  641ea00803c7b1000776183b  RELIANCE        EQ              N
# 2547  641ea0125510ab0007ed0b1e  RELIANCE        EQ              N
# 2548  641ea01d5510ab0007ed124f  RELIANCE        EQ              N
#
#       CH_TRADE_HIGH_PRICE  CH_TRADE_LOW_PRICE  CH_OPENING_PRICE  \
# 0                 2220.00             2180.00           2215.00
# ...

# %%
x = data["CH_CLOSING_PRICE"].values
x
# Out:
# array([2201.25, 2269.7 , 2276.6 , ...,  818.1 ,  812.95,  814.1 ])
